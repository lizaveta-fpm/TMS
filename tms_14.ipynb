# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('C:/3курс/DS/BostonHousing.csv')
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
cr = df["crim"]
cr
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: crim, Length: 506, dtype: float64

# %%
cr.sort_values()
# Out:
# 0       0.00632
# 284     0.00906
# 285     0.01096
# 341     0.01301
# 55      0.01311
#          ...
# 414    45.74610
# 410    51.13580
# 405    67.92080
# 418    73.53410
# 380    88.97620
# Name: crim, Length: 506, dtype: float64

# %%
ag = df["age"]
ag
# Out:
# 0      65.2
# 1      78.9
# 2      61.1
# 3      45.8
# 4      54.2
#        ...
# 501    69.1
# 502    76.7
# 503    91.0
# 504    89.3
# 505    80.8
# Name: age, Length: 506, dtype: float64

# %%
ag.sort_values()
# Out:
# 41       2.9
# 74       6.0
# 73       6.2
# 43       6.5
# 42       6.6
#        ...
# 158    100.0
# 151    100.0
# 146    100.0
# 31     100.0
# 8      100.0
# Name: age, Length: 506, dtype: float64

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(y=df['age'])  
plt.title('Бокс-плот ')
plt.ylabel('возраст')
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(y=df['crim'])  
plt.title('Бокс-плот уровня преступности')
plt.ylabel('Уровень преступности')
plt.show()

# %%
plt.title('')
plt.ylabel('Уровень преступности на душу населения по городам.')
plt.xlabel('кол-во')
#plt.figure();
cr.plot();

# %%
plt.title('Kernel Density Estimation')
plt.xlabel('Возраст')
ag.plot.kde();

# %%
cr.plot.kde();

# %%
df.plot.hexbin(x="dis", y="rm", gridsize=25);
plt.title('Hexagonal bin plot')
plt.ylabel('Среднее количество комнат в жилище')
plt.xlabel('Взвешенные расстояния до центров занятости Бостона')
plt.show()

# %%
df.plot.scatter(x="rad", y="dis", c="age", s=50);

# %%
ax = df.plot.scatter(x="dis", y="indus", color="DarkBlue", label="Group 1")

df.plot.scatter(x="rm", y="lstat", color="DarkGreen", label="Group 2", ax=ax);

# %%
df.plot.scatter(x="dis", y="rm", c="age", cmap="viridis", s=50);

# %%
df.plot.scatter(x="dis", y="rm");

# %%
import seaborn as sns
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)
plt.title('medv', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
sns.histplot(data=df, x="medv")
plt.show()

# %%
sns.lmplot(y ="crim", x ="medv", data=df,
           lowess=True, line_kws={"color": "C1"});

# %%
sns.lmplot(y ="lstat", x ="medv", data=df,
           lowess=True, line_kws={"color": "C1"});

# %%
sns.lmplot(y ="chas", x ="medv", data=df,
           lowess=True, line_kws={"color": "C1"});

# %%
your_columns = ["medv", "age", "salary", "price", "height", "weight"]
for column in your_columns:
    plt.figure()  # это создает новое окно
    sns.histplot(data=df, x="medv")
    plt.title(f'Распределение {"medv"}')
    
plt.show()
