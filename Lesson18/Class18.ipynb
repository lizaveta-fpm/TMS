# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import seaborn.objects as so
df = pd.read_csv('C:/3курс/DS/Tested.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#df['Sex'] = df['Sex'].astype(int64)
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df['Sex'] = df['Sex'].map({'male': 1, 'female': 2}).astype(int)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    1  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    2  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                              Wirz, Mr. Albert    1  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    2  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Embarked'] = df['Embarked'].map({'Q': 1, 'S': 2, 'C': 3}).astype(int)

# %%
df.drop('Name', axis=1)
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0            892         0       3    1  34.5      0      0
# 1            893         1       3    2  47.0      1      0
# 2            894         0       2    1  62.0      0      0
# 3            895         0       3    1  27.0      0      0
# 4            896         1       3    2  22.0      1      1
# ..           ...       ...     ...  ...   ...    ...    ...
# 413         1305         0       3    1   NaN      0      0
# 414         1306         1       1    2  39.0      0      0
# 415         1307         0       3    1  38.5      0      0
# 416         1308         0       3    1   NaN      0      0
# 417         1309         0       3    1   NaN      1      1
#
#                  Ticket      Fare Cabin  Embarked
# 0                330911    7.8292   NaN         1
# 1                363272    7.0000   NaN         2
# 2                240276    9.6875   NaN         1
# 3                315154    8.6625   NaN         2
# 4               3101298   12.2875   NaN         2
# ..                  ...       ...   ...       ...
# 413           A.5. 3236    8.0500   NaN         2
# 414            PC 17758  108.9000  C105         3
# 415  SOTON/O.Q. 3101262    7.2500   NaN         2
# 416              359309    8.0500   NaN         2
# 417                2668   22.3583   NaN         3
#
# [418 rows x 11 columns]

# %%
del df['Ticket']

# %%
df.drop('Name', axis=1)
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare Cabin  \
# 0            892         0       3    1  34.5      0      0    7.8292   NaN
# 1            893         1       3    2  47.0      1      0    7.0000   NaN
# 2            894         0       2    1  62.0      0      0    9.6875   NaN
# 3            895         0       3    1  27.0      0      0    8.6625   NaN
# 4            896         1       3    2  22.0      1      1   12.2875   NaN
# ..           ...       ...     ...  ...   ...    ...    ...       ...   ...
# 413         1305         0       3    1   NaN      0      0    8.0500   NaN
# 414         1306         1       1    2  39.0      0      0  108.9000  C105
# 415         1307         0       3    1  38.5      0      0    7.2500   NaN
# 416         1308         0       3    1   NaN      0      0    8.0500   NaN
# 417         1309         0       3    1   NaN      1      1   22.3583   NaN
#
#      Embarked
# 0           1
# 1           2
# 2           1
# 3           2
# 4           2
# ..        ...
# 413         2
# 414         3
# 415         2
# 416         2
# 417         3
#
# [418 rows x 10 columns]

# %%
df['Cabin'].fillna(0)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#        ...
# 413       0
# 414    C105
# 415       0
# 416       0
# 417       0
# Name: Cabin, Length: 418, dtype: object

# %%
df['Age'] = df.groupby(['Pclass', 'Sex'])['Age'].transform(lambda x : x.fillna(x.median()))

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    2  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                                Wirz, Mr. Albert    1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    2  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    1  24.0      0      0
# 414                  Oliva y Ocana, Dona. Fermina    2  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    1  38.5      0      0
# 416                           Ware, Mr. Frederick    1  24.0      0      0
# 417                      Peter, Master. Michael J    1  24.0      1      1
#
#          Fare Cabin  Embarked
# 0      7.8292   NaN         1
# 1      7.0000   NaN         2
# 2      9.6875   NaN         1
# 3      8.6625   NaN         2
# 4     12.2875   NaN         2
# ..        ...   ...       ...
# 413    8.0500   NaN         2
# 414  108.9000  C105         3
# 415    7.2500   NaN         2
# 416    8.0500   NaN         2
# 417   22.3583   NaN         3
#
# [418 rows x 11 columns]

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    2  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                                Wirz, Mr. Albert    1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    2  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    1  24.0      0      0
# 414                  Oliva y Ocana, Dona. Fermina    2  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    1  38.5      0      0
# 416                           Ware, Mr. Frederick    1  24.0      0      0
# 417                      Peter, Master. Michael J    1  24.0      1      1
#
#          Fare Cabin  Embarked
# 0      7.8292   NaN         1
# 1      7.0000   NaN         2
# 2      9.6875   NaN         1
# 3      8.6625   NaN         2
# 4     12.2875   NaN         2
# ..        ...   ...       ...
# 413    8.0500   NaN         2
# 414  108.9000  C105         3
# 415    7.2500   NaN         2
# 416    8.0500   NaN         2
# 417   22.3583   NaN         3
#
# [418 rows x 11 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    2  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                                Wirz, Mr. Albert    1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    2  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    1  24.0      0      0
# 414                  Oliva y Ocana, Dona. Fermina    2  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    1  38.5      0      0
# 416                           Ware, Mr. Frederick    1  24.0      0      0
# 417                      Peter, Master. Michael J    1  24.0      1      1
#
#          Fare Cabin  Embarked
# 0      7.8292   NaN         1
# 1      7.0000   NaN         2
# 2      9.6875   NaN         1
# 3      8.6625   NaN         2
# 4     12.2875   NaN         2
# ..        ...   ...       ...
# 413    8.0500   NaN         2
# 414  108.9000  C105         3
# 415    7.2500   NaN         2
# 416    8.0500   NaN         2
# 417   22.3583   NaN         3
#
# [418 rows x 11 columns]

# %%
del df['Name']

# %%
titanic = df.fillna(0)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare Cabin  \
# 0            892         0       3    1  34.5      0      0    7.8292     0
# 1            893         1       3    2  47.0      1      0    7.0000     0
# 2            894         0       2    1  62.0      0      0    9.6875     0
# 3            895         0       3    1  27.0      0      0    8.6625     0
# 4            896         1       3    2  22.0      1      1   12.2875     0
# ..           ...       ...     ...  ...   ...    ...    ...       ...   ...
# 413         1305         0       3    1  24.0      0      0    8.0500     0
# 414         1306         1       1    2  39.0      0      0  108.9000  C105
# 415         1307         0       3    1  38.5      0      0    7.2500     0
# 416         1308         0       3    1  24.0      0      0    8.0500     0
# 417         1309         0       3    1  24.0      1      1   22.3583     0
#
#      Embarked
# 0           1
# 1           2
# 2           1
# 3           2
# 4           2
# ..        ...
# 413         2
# 414         3
# 415         2
# 416         2
# 417         3
#
# [418 rows x 10 columns]

# %%
a[i] == 0
for i in range (0, 417): 
     a[i] = df.at[i, 'Cabin'] 
     if a[i] != 0:
        df.at[i, 'Cabin'] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 a[i] == 0
#       2 for i in range (0, 417):
#       3      a[i] = df.at[i, 'Cabin']
#
# NameError: name 'a' is not defined

# %%
titanic['Cabin'] = titanic['Cabin'].apply(lambda x: 1 if x != 0 else 0)

# %%
df['Cabin'] = (df['Cabin'] != 0).astype(int)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Cabin  \
# 0            892         0       3    1  34.5      0      0    7.8292      0
# 1            893         1       3    2  47.0      1      0    7.0000      0
# 2            894         0       2    1  62.0      0      0    9.6875      0
# 3            895         0       3    1  27.0      0      0    8.6625      0
# 4            896         1       3    2  22.0      1      1   12.2875      0
# ..           ...       ...     ...  ...   ...    ...    ...       ...    ...
# 413         1305         0       3    1  24.0      0      0    8.0500      0
# 414         1306         1       1    2  39.0      0      0  108.9000      1
# 415         1307         0       3    1  38.5      0      0    7.2500      0
# 416         1308         0       3    1  24.0      0      0    8.0500      0
# 417         1309         0       3    1  24.0      1      1   22.3583      0
#
#      Embarked
# 0           1
# 1           2
# 2           1
# 3           2
# 4           2
# ..        ...
# 413         2
# 414         3
# 415         2
# 416         2
# 417         3
#
# [418 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)
plt.title('Survived', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
sns.histplot(data=titanic, y="Survived", bins=20, color='skyblue')
# Out:
# <Axes: xlabel='Count', ylabel='Survived'>

# %%
sns.lmplot(y ="Age", x ="Survived", data=df,
           lowess=True, line_kws={"color": "C1"});

# %%
sns.lmplot(y ="Embarked", x ="Survived", data=df,
           lowess=True, line_kws={"color": "C1"});

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=titanic, x="Sex",y = 'Age', hue="Survived")
plt.xlabel('Пол')
plt.ylabel('Возраст')
plt.title('Выжившие в зависимости от пола и возраста')
plt.show()

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   418.000000  418.000000  418.000000  418.000000  418.000000
# mean   1100.500000    0.363636    2.265550    1.363636   29.297847
# std     120.810458    0.481622    0.841838    0.481622   13.038856
# min     892.000000    0.000000    1.000000    1.000000    0.170000
# 25%     996.250000    0.000000    1.000000    1.000000   22.000000
# 50%    1100.500000    0.000000    3.000000    1.000000   25.000000
# 75%    1204.750000    1.000000    3.000000    2.000000   36.375000
# max    1309.000000    1.000000    3.000000    2.000000   76.000000
#
#             SibSp       Parch        Fare       Cabin    Embarked
# count  418.000000  418.000000  418.000000  418.000000  418.000000
# mean     0.447368    0.392344   35.541956    0.217703    2.133971
# std      0.896760    0.981429   55.867684    0.413179    0.580452
# min      0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      0.000000    0.000000    7.895800    0.000000    2.000000
# 50%      0.000000    0.000000   14.454200    0.000000    2.000000
# 75%      1.000000    0.000000   31.471875    0.000000    2.000000
# max      8.000000    9.000000  512.329200    1.000000    3.000000

# %%
x = titanic.drop(columns=["Survived"])
y = titanic["Survived"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
x, y, test_size=0.1, random_state=42)

# %%
X_train
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare  Cabin  Embarked
# 110         1002       2    1  41.0      0      0  15.0458      0         3
# 290         1182       1    1  42.0      0      0  39.6000      0         2
# 73           965       1    1  28.5      0      0  27.7208      1         3
# 261         1153       3    1  21.0      0      0   7.8542      0         2
# 365         1257       3    2  22.0      1      9  69.5500      0         2
# ..           ...     ...  ...   ...    ...    ...      ...    ...       ...
# 71           963       3    1  21.0      0      0   7.8958      0         2
# 106          998       3    1  21.0      0      0   7.8208      0         1
# 270         1162       1    1  46.0      0      0  75.2417      1         3
# 348         1240       2    1  24.0      0      0  13.5000      0         2
# 102          994       3    1  24.0      0      0   7.7500      0         1
#
# [376 rows x 9 columns]

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)

# %%
reg.coef_
# Out:
# array([ 2.05410902e-18, -2.52575738e-15,  1.00000000e+00,  2.70616862e-16,
#        -1.51137783e-16,  2.00577402e-16, -1.02348685e-16,  7.56556276e-16,
#         1.39536820e-16])

# %%
reg.intercept_
# Out:
# np.float64(-1.0000000000000013)

# %%
reg.predict(X_test)
# Out:
# array([ 6.66133815e-16,  1.00000000e+00, -1.33226763e-15,  1.77635684e-15,
#         1.00000000e+00,  6.21724894e-15,  1.00000000e+00,  8.88178420e-15,
#         1.00000000e+00, -4.44089210e-16, -3.99680289e-15,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00, -4.44089210e-16, -6.10622664e-15,
#         1.00000000e+00,  9.32587341e-15, -7.66053887e-15,  1.33226763e-15,
#         1.04360964e-14,  4.66293670e-15,  1.00000000e+00,  2.66453526e-15,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  7.10542736e-15,
#         4.21884749e-15,  2.44249065e-15, -2.22044605e-16,  1.00000000e+00,
#         1.00000000e+00, -1.11022302e-15,  1.00000000e+00,  1.55431223e-15,
#         1.00000000e+00,  3.10862447e-15,  1.00000000e+00, -1.35447209e-14,
#         1.00000000e+00,  1.00000000e+00])

# %%
y_predict = reg.predict(X_test)
y_true = titanic.loc[X_test.index, "Survived"] 
err = y_true - y_predict
new_list = list(err)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression(max_iter = 5000).fit(X_train, y_train)
